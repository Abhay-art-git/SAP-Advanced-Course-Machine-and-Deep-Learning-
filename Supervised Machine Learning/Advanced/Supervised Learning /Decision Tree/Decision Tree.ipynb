# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("decison_dataset.csv")

# %%
dataset.head()
# Out:
#    Age  E_salary  placement
# 0   19     23000          0
# 1   25     24000          0
# 2   27     26000          1
# 3   24    120000          1
# 4   18     29000          0

# %%
x = dataset.iloc[:,:-1]
y = dataset["placement"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(max_depth=5)

# %%
dt.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
dt.score(x_test, y_test)*100
# Out:
# 50.0

# %%
dt.predict([[18,29000]])
# Out:
# C:\Users\mahto\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
dt.score(x_train, y_train)*100
# Out:
# 90.0

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(dt)
plt.show()
