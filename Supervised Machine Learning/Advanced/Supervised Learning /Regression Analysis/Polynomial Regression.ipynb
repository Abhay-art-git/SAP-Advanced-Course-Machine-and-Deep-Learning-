# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Book2.csv")

# %%
dataset.head(3)
# Out:
#    Level  Salary
# 0      1    1798
# 1      2    3981
# 2      3    7874

# %%
plt.scatter(dataset["Level"],dataset["Salary"])
plt.show()

# %%
x = dataset[["Level"]]
y = dataset[["Salary"]]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree=2)
pf.fit(x)
x=pf.transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2 , random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)*100
# Out:
# 99.99241912118549

# %%
pred = lr.predict(x)

# %%
plt.scatter(dataset["Level"],dataset["Salary"])
plt.plot(dataset["Level"],pred , c="red")
plt.show()

# %%
test = pf.transform([[14]])
test
# Out:
# C:\Users\mahto\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([[  1.,  14., 196.]])

# %%
lr.predict(test)
# Out:
# array([[111708.59429161]])
