# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("LR.csv")

# %%
dataset.head(3)
# Out:
#    Age  Estimated Salary  Purchased
# 0   19           19000.0          0
# 1   35           20000.0          0
# 2   26           43000.0          0

# %%
dataset.drop(columns="Estimated Salary", inplace=True)

# %%
dataset
# Out:
#     Age  Purchased
# 0    19          0
# 1    35          0
# 2    26          0
# 3    27          0
# 4    19          0
# 5    27          0
# 6    27          0
# 7    32          1
# 8    25          0
# 9    35          0
# 10   26          0
# 11   26          0
# 12   20          0
# 13   23          1
# 14   12          0
# 15   34          1
# 16   23          0
# 17   56          0
# 18   45          1
# 19   34          0
# 20   25          1
# 21   27          0
# 22   22          1
# 23   18          0
# 24   33          1
# 25   38          1
# 26   11          0
# 27   16          1

# %%
sns.scatterplot(x="Age", y="Purchased" , data = dataset)
plt.show()

# %%
x = dataset[["Age"]]
y = dataset["Purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test ,y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 83.33333333333334

# %%
lr.predict([[40]])
# Out:
# C:\Users\mahto\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
sns.scatterplot(x="Age", y="Purchased" , data = dataset)

sns.lineplot(x="Age" , y=lr.predict(x), data = dataset)
plt.show()
