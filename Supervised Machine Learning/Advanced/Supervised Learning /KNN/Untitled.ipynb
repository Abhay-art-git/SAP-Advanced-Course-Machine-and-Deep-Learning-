# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("decison_dataset.csv")

# %%
dataset.isnull().sum()
# Out:
# Age         0
# E_salary    0
# Purchase    0
# dtype: int64

# %%
sns.scatterplot(x="Age",y="E_salary" , data=dataset , hue="Purchase")
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["Purchase"]
