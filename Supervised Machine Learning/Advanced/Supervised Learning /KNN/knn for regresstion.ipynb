# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("world bank.csv")

# %%
dataset.head()
# Out:
#    Year  Birth rate, crude (per 1,000 people)  \
# 0  2014                                12.259
# 1  2013                                12.257
# 2  2012                                12.197
# 3  2011                                12.100
# 4  2010                                12.001
#
#    Death rate, crude (per 1,000 people)  \
# 0                                 7.219
# 1                                 7.096
# 2                                 6.996
# 3                                 6.915
# 4                                 6.841
#
#    Electric power consumption (kWh per capita)     GDP (USD)  \
# 0                                      2309.37  1.322820e+10
# 1                                      2533.25  1.277630e+10
# 2                                      2118.33  1.231980e+10
# 3                                      2205.70  1.289090e+10
# 4                                      1943.34  1.192700e+10
#
#    GDP per capita (USD)  Individuals using the Internet (% of population)  \
# 0               4578.67                                            60.100
# 1               4413.08                                            57.200
# 2               4247.61                                            54.656
# 3               4437.18                                            49.000
# 4               4094.36                                            45.000
#
#    Infant mortality rate (per 1,000 live births)  \
# 0                                            8.9
# 1                                            9.5
# 2                                           10.2
# 3                                           11.0
# 4                                           11.9
#
#    Life expectancy at birth (years)  \
# 0                            77.813
# 1                            77.554
# 2                            77.252
# 3                            76.914
# 4                            76.562
#
#    Population density (people per sq. km of land area)  \
# 0                                            105.442
# 1                                            105.660
# 2                                            105.854
# 3                                            106.029
# 4                                            106.315
#
#    Unemployment (% of total labor force) (modeled ILO estimate)
# 0                                             17.490
# 1                                             15.866
# 2                                             13.376
# 3                                             13.481
# 4                                             14.086

# %%
x = dataset.iloc[:,:-1]
y = dataset["Unemployment (% of total labor force) (modeled ILO estimate)"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,random_state=42,test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(x_train , y_train)
# Out:
# KNeighborsRegressor()

# %%
knn.score(x_test , y_test)*100
# Out:
# 8.150269634338725

# %%
for i in range(1,20):
    knn1 = KNeighborsRegressor(n_neighbors=i)
    print(i,knn.score(x_train , y_train)*100 , knn.score(x_test , y_test)*100)
# Out:
# 1 48.62209702906984 8.150269634338725
# 2 48.62209702906984 8.150269634338725
# 3 48.62209702906984 8.150269634338725
# 4 48.62209702906984 8.150269634338725
# 5 48.62209702906984 8.150269634338725
# 6 48.62209702906984 8.150269634338725
# 7 48.62209702906984 8.150269634338725
# 8 48.62209702906984 8.150269634338725
# 9 48.62209702906984 8.150269634338725
# 10 48.62209702906984 8.150269634338725
# 11 48.62209702906984 8.150269634338725
# 12 48.62209702906984 8.150269634338725
# 13 48.62209702906984 8.150269634338725
# 14 48.62209702906984 8.150269634338725
# 15 48.62209702906984 8.150269634338725
# 16 48.62209702906984 8.150269634338725
# 17 48.62209702906984 8.150269634338725
# 18 48.62209702906984 8.150269634338725
# 19 48.62209702906984 8.150269634338725
