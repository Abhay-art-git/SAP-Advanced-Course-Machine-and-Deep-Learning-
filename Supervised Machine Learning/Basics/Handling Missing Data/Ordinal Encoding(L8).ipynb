# %%
import pandas as pd

# %%
df = pd.DataFrame({"Size":["s","m","l","xl","m","l","xl"]})
df.head(5)
# Out:
#   Size
# 0    s
# 1    m
# 2    l
# 3   xl
# 4    m

# %%
ord_data=[["s","m","l","xl"]]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=ord_data)
oe.fit(df[["Size"]])
# Out:
# OrdinalEncoder(categories=[['s', 'm', 'l', 'xl']])

# %%
df["Size_en"]=oe.transform(df[["Size"]])

# %%
df
# Out:
#   Size  Size_en
# 0    s      0.0
# 1    m      1.0
# 2    l      2.0
# 3   xl      3.0
# 4    m      1.0
# 5    l      2.0
# 6   xl      3.0

# %%
ord_data1={"s":0,"m":1,"l":2,"xl":3}

# %%
df["Size_map"]=df["Size"].map(ord_data1)

# %%
df
# Out:
#   Size  Size_en  Size_map
# 0    s      0.0         0
# 1    m      1.0         1
# 2    l      2.0         2
# 3   xl      3.0         3
# 4    m      1.0         1
# 5    l      2.0         2
# 6   xl      3.0         3

# %%
x = pd.read_csv("Student.csv")

# %%
x["Married"].unique
# Out:
# <bound method Series.unique of 0     no
# 1    yes
# 2    yes
# 3     no
# 4     no
# 5    yes
# 6     no
# 7    yes
# Name: Married, dtype: object>

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories= data1)

# %%
data1 = [["yes","no"]]

# %%
x["Married_Encoding"]=oe.fit_transform(x[["Married"]])

# %%
x
# Out:
#     Name  Class    no.  age gender   weight Married  Married_Encoding
# 0   Abhi      11  9909   20    male     187      no               1.0
# 1  Sumit      12  3674   19    male     156     yes               0.0
# 2    Raj      11  7895   17    male     145     yes               0.0
# 3   Ajay      10  6785   16    male     134      no               1.0
# 4   Anuj       9  8965   20    male     176      no               1.0
# 5   rina       8  7896   19  female     179     yes               0.0
# 6   riya      12  6789   18  female     165      no               1.0
# 7   anju      11  9876   17  female     167     yes               0.0

# %%
x
# Out:
#     Name  Class    no.  age gender   weight Married  Married_Encoding
# 0   Abhi      11  9909   20    male     187      no               1.0
# 1  Sumit      12  3674   19    male     156     yes               0.0
# 2    Raj      11  7895   17    male     145     yes               0.0
# 3   Ajay      10  6785   16    male     134      no               1.0
# 4   Anuj       9  8965   20    male     176      no               1.0
# 5   rina       8  7896   19  female     179     yes               0.0
# 6   riya      12  6789   18  female     165      no               1.0
# 7   anju      11  9876   17  female     167     yes               0.0
