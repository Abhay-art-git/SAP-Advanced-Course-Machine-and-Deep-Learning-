# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = pd.read_csv("Diabetes Missing Data.csv")
x
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
x.isnull().sum()
# Out:
# Pregnant               0
# Glucose                5
# Diastolic_BP          35
# Skin_Fold            227
# Serum_Insulin        374
# BMI                   11
# Diabetes_Pedigree      0
# Age                    0
# Class                  0
# dtype: int64

# %%
x["Glucose"].fillna(x["Glucose"].mode())
# Out:
# 0      148.0
# 1       85.0
# 2      183.0
# 3       89.0
# 4      137.0
#        ...
# 763    101.0
# 764    122.0
# 765    121.0
# 766    126.0
# 767     93.0
# Name: Glucose, Length: 768, dtype: float64

# %%
x["Glucose"]
# Out:
# 0      148.0
# 1       85.0
# 2      183.0
# 3       89.0
# 4      137.0
#        ...
# 763    101.0
# 764    122.0
# 765    121.0
# 766    126.0
# 767     93.0
# Name: Glucose, Length: 768, dtype: float64

# %%
sns.distplot(x["Glucose"])
plt.show()
# Out:
# C:\Users\mahto\AppData\Local\Temp\ipykernel_396\662024877.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x["Glucose"])

# %%
x
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
x.describe()
# Out:
#          Pregnant     Glucose  Diastolic_BP   Skin_Fold  Serum_Insulin  \
# count  768.000000  763.000000    733.000000  541.000000     394.000000
# mean     3.845052  121.686763     72.405184   29.153420     155.548223
# std      3.369578   30.535641     12.382158   10.476982     118.775855
# min      0.000000   44.000000     24.000000    7.000000      14.000000
# 25%      1.000000   99.000000     64.000000   22.000000      76.250000
# 50%      3.000000  117.000000     72.000000   29.000000     125.000000
# 75%      6.000000  141.000000     80.000000   36.000000     190.000000
# max     17.000000  199.000000    122.000000   99.000000     846.000000
#
#               BMI  Diabetes_Pedigree         Age       Class
# count  757.000000         768.000000  768.000000  768.000000
# mean    32.457464           0.471876   33.240885    0.348958
# std      6.924988           0.331329   11.760232    0.476951
# min     18.200000           0.078000   21.000000    0.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
ss.fit(x[["Glucose"]])
# Out:
# StandardScaler()

# %%
x["Glucose_ss"]=pd.DataFrame( ss.transform(x[["Glucose"]]) , columns = ["y"])

# %%
x.head(3)
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0            NaN  33.6
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
#
#    Diabetes_Pedigree  Age  Class  Glucose_ss
# 0              0.627   50      1    0.862287
# 1              0.351   31      0   -1.202229
# 2              0.672   32      1    2.009241

# %%
x.describe()
# Out:
#          Pregnant     Glucose  Diastolic_BP   Skin_Fold  Serum_Insulin  \
# count  768.000000  763.000000    733.000000  541.000000     394.000000
# mean     3.845052  121.686763     72.405184   29.153420     155.548223
# std      3.369578   30.535641     12.382158   10.476982     118.775855
# min      0.000000   44.000000     24.000000    7.000000      14.000000
# 25%      1.000000   99.000000     64.000000   22.000000      76.250000
# 50%      3.000000  117.000000     72.000000   29.000000     125.000000
# 75%      6.000000  141.000000     80.000000   36.000000     190.000000
# max     17.000000  199.000000    122.000000   99.000000     846.000000
#
#               BMI  Diabetes_Pedigree         Age       Class    Glucose_ss
# count  757.000000         768.000000  768.000000  768.000000  7.630000e+02
# mean    32.457464           0.471876   33.240885    0.348958  1.070936e-16
# std      6.924988           0.331329   11.760232    0.476951  1.000656e+00
# ...

# %%
sns.distplot(x["Glucose_ss"])
plt.show()
# Out:
# C:\Users\mahto\AppData\Local\Temp\ipykernel_396\2550882591.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x["Glucose_ss"])

# %%
sns.distplot(x["Glucose"])
plt.show()
# Out:
# C:\Users\mahto\AppData\Local\Temp\ipykernel_396\662024877.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x["Glucose"])
